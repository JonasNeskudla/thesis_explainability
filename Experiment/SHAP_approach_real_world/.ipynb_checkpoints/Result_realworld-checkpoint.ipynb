# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
import copy
from os.path import isfile, join
from importnb import Notebook

'''
Objects, which are imported in the following, were created with the class "Backend". 
The subsequent division into 'Backend' and 'Backend_ROC' for multiclass scenarios was
not yet available at this time, which is why 'Backend' is imported here, although new objects
will be created by the 'Backend_ROC'. For this reason, BACKEND_ROC needs to be importetd for newly
created objects.
'''

#ShapDetectorClass = Notebook.load('Backend_ROC.ipynb')
ShapDetectorClass = Notebook.load('Backend.ipynb')

ShapDetector = ShapDetectorClass.ShapDetector

# %%
plt.style.use('ggplot')
plt.style.use('seaborn-white')

# %%
def plot_stats(true_drifts, drift_detections, dist_list, shap_list, score_list, plot_steps, p_list=5):
    plt.figure(figsize = (30,20))
    
    ax1 = plt.subplot(4, 1, 1)
    create_abs_shap_plot(true_drifts, drift_detections, shap_list, plot_steps)
    
    plt.subplot(4, 1, 2, sharex=ax1)
    create_acc_plot(true_drifts, drift_detections, score_list, plot_steps)
    
    plt.subplot(4, 1, 3, sharex=ax1)
    create_dist_plot(true_drifts, drift_detections, dist_list, plot_steps)
    
    plt.subplot(4, 1, 4, sharex=ax1)
    create_shap_plot(true_drifts, drift_detections, shap_list, plot_steps)

    
def create_dist_plot(true_drifts, drift_detections, dist_list, plot_steps, window_size=50):            
    # compute rolling mean of distance
    dist_series = pd.Series(dist_list)
    windows = dist_series.rolling(window_size)
    moving_averages = windows.mean()
    moving_averages_list = moving_averages.tolist()    
    plt.plot(moving_averages_list,  linewidth=1.1, color = 'green')#label = 'Distance', 

    #true drift points
    for d in true_drifts:
        plt.axvline(d, color = 'red', linewidth=1)
    
    #detected drift points
    j = 1
    for i in drift_detections:
        plt.axvline(i, color = 'black', linewidth=0.7)
        j += 1
        
    plt.xticks(np.arange(0, len(dist_list), plot_steps), rotation=20, fontsize= 20)
    plt.xlabel('Processed instances', fontsize = 20)
    #plt.xlim([0, len(dist_list)+1])
    plt.yticks(fontsize = 20)
    plt.ylabel('Distance', fontsize = 20)
    plt.legend()
    
    return 

def create_shap_plot(true_drifts, drift_detections, shap_list, plot_steps, window_size=50):
    shap_transposed = list(map(list, zip(*shap_list)))
        
    cnt=1
    for s_values in shap_transposed:
        dist_series = pd.Series(s_values)
        windows = dist_series.rolling(window_size)
        moving_averages = windows.mean()
        moving_averages_list = moving_averages.tolist()
        plt.plot(moving_averages_list,  linewidth=1.6)#, label = 'F{}'.format(cnt)
        cnt+=1
            
    #true drift points
    for d in true_drifts:
        plt.axvline(d, color = 'red', linewidth=2)
    
    #detected drift points
    j = 1
    for i in drift_detections:
        plt.axvline(i, color = 'black', linewidth=0.2)
        j += 1
    
    plt.xticks(np.arange(0, len(shap_list), plot_steps), rotation=20, fontsize= 20)
    plt.xlabel('Processed instances', fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.ylabel('Shapley Values', fontsize = 20)


    plt.legend()

    return 

def create_abs_shap_plot(true_drifts, drift_detections, shap_list, plot_steps, window_size=50):
    shap_transposed = np.abs(list(map(list, zip(*shap_list))))
        
    cnt=1
    for s_values in shap_transposed:
        dist_series = pd.Series(s_values)
        windows = dist_series.rolling(window_size)
        moving_averages = windows.mean()
        moving_averages_list = moving_averages.tolist()
        plt.plot(moving_averages_list,  linewidth=1.6, label = 'F{}'.format(cnt))
        cnt+=1
    
    #true drift points
    for d in true_drifts:
        plt.axvline(d, color = 'red', linewidth=2.2)
    
    #detected drift points
    j = 1
    for i in drift_detections:
        plt.axvline(i, color = 'black', linewidth=0.5)
        j += 1
        
    plt.xticks(np.arange(0, len(shap_list), plot_steps), rotation=20, fontsize = 20)
    plt.xlabel('Processed instances', fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.ylabel('Absolute Shapley Value', fontsize = 20)

    return 

def create_acc_plot(true_drifts, drift_detections, score_list, plot_steps, window_size=50):    
    # compute rolling mean of accuracy
    dist_series = pd.Series(score_list)
    windows = dist_series.rolling(window_size)
    moving_averages = windows.mean()
    moving_averages_list = moving_averages.tolist()
    plt.plot(moving_averages_list,  linewidth=1,color = 'blue') # label = 'Accuracy', 
    
    # compute rolling mean of f1-score
    dist_series = pd.Series(weighted_f1_list)
    windows = dist_series.rolling(window_size)
    moving_averages = windows.mean()
    moving_averages_list = moving_averages.tolist()
    # additionally plot F1-score
    #plt.plot(moving_averages_list,  linewidth=1.1, label = 'Weighted F1', color = 'orange')
    
    
    #true drift points
    for d in true_drifts:
        plt.axvline(d, color = 'red', linewidth=2.2)
    
    #detected drift points
    j = 1
    for i in drift_detections:
        plt.axvline(i, color = 'black', linewidth=0.5)
        j += 1
        
    plt.xticks(np.arange(0, len(score_list), plot_steps), rotation=20, fontsize=20)
    plt.xlabel('Processed instances', fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.ylabel('Accuracy Score', fontsize = 20)
    plt.legend()
    
    return

# %%
# get filenames
path = "../Results/Detector_objs/Test_insects_abrupt_red" 
#path = "../Results/Detector_objs/Test_insects_inc_abr_red"
#path = "../Results/Detector_objs/Test_insects_inc_abr_full_set_of_features"
#path = "../Results/Detector_objs/Test_insects_inc_abr_red" 
#path = "../Results/Detector_objs/Validation_insects_abrupt_red" 
#path = "../Results/Detector_objs/Validation_insects_incr_abr_red" 

files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
#files.remove('.DS_Store')
#files

# %%
# get all detectors from folder
acc_list = []
detector_list = []
for f in files:
     if f != '.DS_Store': # to exemplary plot an object, containing Shapley Values due to explanation-based detection add the following: "and f == '2020_11_05_02_00_58_758.pickle':""
        d = pickle.load(open("{0}/{1}".format(path,f), "rb"))
        detector_list.append(d)   
        
        # store accuracy in case of no retraining option for later plotting
        if d.ad_delta == 9999: #no retraining 
            acc_list = d.score_list
    
     else:
        print('Achtung, DS Store nicht gelöscht!')

# %%
# plot and store results
df_statistics = pd.DataFrame()
for idx,detector in enumerate(detector_list):
    # Plots
    shap_list  = detector.shap_list
    score_list = detector.score_list
    weighted_f1_list = detector.weighted_f1_list
    dist_list = detector.distances
    drift_detections = detector.drift_detections
    true_drifts = detector.true_drift_points
    
    plt.clf()
    plot_steps = 5000
    fig = plot_stats(true_drifts, drift_detections, dist_list, shap_list, score_list, plot_steps = plot_steps)#, p_list)

    #plt.savefig("../Results/Plots/{0}_Plot.jpg".format(files[idx]))
    
    # Table
    statistics = detector.get_statistics(drift_range=0)
    statistics["filename"] = files[idx]
    df_statistics = df_statistics.append(statistics, ignore_index=True, sort=False)
    

# if only the accuracy curve is plottet, the corresponding object origins from a test run with performance-based detection enabled

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)  
cols = [
        'filename', 'Model', 'Error Based', 
        'Initial Instances', 'Approach', 'Retrainsize', 'Samplesize', 
        'Base Detector',
        'Ad Delta',
        'Ks Alpha',
        'Ph Alpha', 'Ph Delta','Ph Min Inst', 'Ph Threshold', 
        'FAC','MDC', 'MDR', 'MTD', 'MTFA', 'MTR', 'True Drift Points', 'Triggered Drifts', 'Detections Count',
        'Labels Detection %','Labels Retraining %','Sampling', 'Weighted F1', 'Mcc', 'ROC_AUC', 'Acc']

df_statistics = df_statistics[cols]
df_statistics.sort_values(by=['ROC_AUC','Acc', 'Ad Delta'], ascending=[False,False, False], inplace=True)
df_statistics
# Out:
#                           filename Model Error Based  Initial Instances  \
# 6   2020_11_09_12_34_31_337.pickle    Xg        True             2642.0
# 3   2020_11_09_12_30_42_478.pickle    Xg        True             2642.0
# 11  2020_11_09_12_26_43_551.pickle    Xg        True             2642.0
# 1   2020_11_09_12_47_23_389.pickle    Xg        True             2642.0
# 9   2020_11_09_12_42_46_375.pickle    Xg        True             2642.0
# 0   2020_11_09_12_59_31_148.pickle    Xg        True             2642.0
# 4   2020_11_09_12_51_14_481.pickle    Xg        True             2642.0
# 12  2020_11_09_12_38_55_675.pickle    Xg        True             2642.0
# 8   2020_11_09_12_55_41_995.pickle    Xg        True             2642.0
# 2   2020_11_09_12_22_58_435.pickle    Xg        True             2642.0
# 7   2020_11_09_12_19_08_372.pickle    Xg        True             2642.0
# 5   2020_11_09_12_15_25_592.pickle    Xg        True             2642.0
# 10  2020_11_05_02_00_58_758.pickle    Xg       False             2642.0
#
#     Approach  Retrainsize  Samplesize Base Detector  Ad Delta Ks Alpha  \
# 6   Standard        528.0         1.0         adwin     0.001     None
# 3   Standard        528.0         1.0         adwin     0.001     None
# 11  Standard        528.0         1.0         adwin     0.001     None
# 1   Standard        528.0         1.0         adwin     0.001     None
# 9   Standard        528.0         1.0         adwin     0.001     None
# 0   Standard        528.0         1.0         adwin     0.001     None
# 4   Standard        528.0         1.0         adwin     0.001     None
# 12  Standard        528.0         1.0         adwin     0.001     None
# 8   Standard        528.0         1.0         adwin     0.001     None
# 2   Standard        528.0         1.0         adwin     0.001     None
# 7   Standard        528.0         1.0         adwin     0.001     None
# 5   Standard          0.0         1.0         adwin  9999.000     None
# 10  Standard          0.0         1.0         adwin  9999.000     None
#
#    Ph Alpha Ph Delta Ph Min Inst Ph Threshold  FAC   MDC    MDR      MTD  \
# 6      None     None        None         None  0.0   2.0  0.182  345.222
# 3      None     None        None         None  0.0   2.0  0.182  569.222
# 11     None     None        None         None  0.0   2.0  0.182  736.333
# 1      None     None        None         None  0.0   2.0  0.182  532.556
# 9      None     None        None         None  0.0   2.0  0.182  482.778
# 0      None     None        None         None  0.0   4.0  0.364  564.429
# 4      None     None        None         None  0.0   3.0  0.273  524.250
# 12     None     None        None         None  0.0   3.0  0.273  451.750
# 8      None     None        None         None  0.0   4.0  0.364  573.571
# 2      None     None        None         None  0.0   3.0  0.273  467.000
# 7      None     None        None         None  0.0   4.0  0.364  981.571
# 5      None     None        None         None  0.0  11.0  1.000    0.000
# 10     None     None        None         None  0.0  11.0  1.000    0.000
#
#     MTFA  MTR                                  True Drift Points  \
# 6    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 3    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 11   0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 1    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 9    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 0    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 4    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 12   0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 8    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 2    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 7    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 5    0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 10   0.0  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
#
#                                      Triggered Drifts  Detections Count  \
# 6   [10175, 11807, 17439, 25631, 30911, 35743, 363...               9.0
# 3   [10175, 11839, 19007, 25791, 30847, 35775, 366...               9.0
# 11  [10175, 11839, 19007, 25983, 30847, 35903, 363...               9.0
# 1   [10175, 11839, 26623, 30815, 35903, 36159, 379...               9.0
# 9   [10175, 11839, 26175, 30687, 35775, 36191, 381...               9.0
# 0   [10175, 11839, 26687, 30687, 37375, 45311, 49503]               7.0
# 4   [10175, 11839, 26623, 30719, 35999, 37343, 451...               8.0
# 12  [10175, 11839, 26687, 30783, 35711, 36287, 449...               8.0
# 8   [10175, 11839, 26751, 30623, 37279, 45471, 49503]               7.0
# 2   [10175, 11935, 15871, 16991, 31359, 35839, 376...               8.0
# 7   [10175, 11999, 17183, 29471, 30623, 35775, 38079]               7.0
# 5                                                  []               0.0
# 10                                                 []               0.0
#
#     Labels Detection %  Labels Retraining % Sampling  Weighted F1    Mcc  \
# 6                100.0                 60.0   margin        0.655  0.589
# 3                100.0                 40.0  entropy        0.630  0.564
# 11               100.0                 40.0   margin        0.620  0.549
# 1                100.0                 80.0  entropy        0.604  0.522
# 9                100.0                 80.0   margin        0.604  0.522
# 0                100.0                100.0        -        0.599  0.516
# 4                100.0                 90.0   margin        0.597  0.515
# 12               100.0                 60.0  entropy        0.594  0.511
# 8                100.0                 90.0  entropy        0.591  0.508
# 2                100.0                 20.0  entropy        0.579  0.502
# 7                100.0                 20.0   margin        0.562  0.488
# 5                100.0                100.0        -        0.532  0.485
# 10                 0.0                100.0        -        0.532  0.485
#
#     ROC_AUC    Acc
# 6     0.918  0.657
# 3     0.907  0.635
# 11    0.906  0.623
# 1     0.895  0.601
# 9     0.893  0.601
# 0     0.892  0.596
# 4     0.891  0.595
# 12    0.891  0.592
# 8     0.887  0.590
# 2     0.882  0.583
# 7     0.874  0.571
# 5     0.866  0.563
# 10    0.866  0.563

# %% [markdown]
# ### Further Plots

# %%
# Sort out objects that should not be plotted.
df_statistics = df_statistics[df_statistics['Ad Delta']!=9999] # sort out "no retraining" option
df_statistics = df_statistics[df_statistics['Error Based'] == 'True'] # sort out explanations-based runs
df_statistics = df_statistics[df_statistics['Base Detector']!='kswin'] # sort out runs with KSWIN detector
df_statistics = copy.deepcopy(df_statistics)
# .. further sorting out if needed ..

# %%
import matplotlib as mpl
plt.style.use('seaborn-white')
norm = mpl.colors.Normalize(vmin=5, vmax=10)
cmap = mpl.cm.coolwarm
fig, ax = plt.subplots(1)

plt.scatter(x = df_statistics['Detections Count'], y = df_statistics['ROC_AUC'], c = df_statistics['Labels Retraining %'], cmap=plt.cm.coolwarm, s = 180)
plt.xlabel("Number of detected drifts", fontsize = 30)
plt.xticks(np.arange(min(df_statistics['Detections Count']), max(df_statistics['Detections Count'])+1, 1), fontsize = 30)

plt.ylabel("AUC", fontsize = 30)
plt.yticks(fontsize = 30)

cbar = plt.colorbar()
cbar.set_ticklabels(np.arange(0, int(100)+1, 5))
cbar.ax.tick_params(labelsize=25)
cbar.set_label("Labels Retraining %", labelpad=1, color='black', fontsize= 30)

fig.set_size_inches(15,8)
fig.tight_layout() 
#plt.savefig("../Results/1_ins_INC_ABR_all.jpg")
plt.show()
# Out:
# set_ticks() must have been called.

# %%
import matplotlib as mpl
norm = mpl.colors.Normalize(vmin=5, vmax=10)
cmap = mpl.cm.hot
fig, ax = plt.subplots(1)


plt.scatter(x = df_statistics['MTD'], y = df_statistics['ROC_AUC'], c = df_statistics['Labels Retraining %'], cmap=plt.cm.coolwarm, s= 180 ) 
plt.xlabel("Mean time to detection", fontsize=30)
plt.xticks(np.arange(np.round(min(df_statistics['MTD'])), np.round(max(df_statistics['MTD'])+1), 100), fontsize=30)

plt.ylabel("AUC", fontsize=30)
plt.yticks(fontsize = 30)

cbar = plt.colorbar()
cbar.set_ticklabels(np.arange(0, int(100)+1, 5))
cbar.ax.tick_params(labelsize=25)
cbar.set_label("Labels Retraining %", labelpad=1, color='black', fontsize= 30)

fig.set_size_inches(15,8)
fig.tight_layout() 
#plt.savefig("../Results/2_ins_INC_ABR_all.jpg")
plt.show()
# Out:
# set_ticks() must have been called.

# %%
import matplotlib as mpl
norm = mpl.colors.Normalize(vmin=5, vmax=10)
cmap = mpl.cm.hot
fig, ax = plt.subplots(1)


plt.scatter(x = df_statistics['Detections Count'], y = df_statistics['ROC_AUC'], c = df_statistics['MTD'], cmap=plt.cm.coolwarm, s= 180) 
plt.xlabel("Number of detected drifts", fontsize=30)
plt.xticks(np.arange(min(df_statistics['Detections Count']), max(df_statistics['Detections Count'])+1, 1), fontsize=30)

plt.ylabel("AUC", fontsize=30)
plt.yticks(fontsize = 30)


cbar = plt.colorbar()
cbar.set_ticklabels(np.arange(min(df_statistics['MTD']), max(df_statistics['MTD'])+1, 100))
cbar.ax.tick_params(labelsize=25)
cbar.set_label("MTD", labelpad=1, color='black', fontsize=30)


fig.set_size_inches(15,8)
fig.tight_layout() 
#plt.savefig("../Results/3_ins_INC_ABR_all.jpg")
plt.show()
# Out:
# set_ticks() must have been called.

# %%
df = copy.deepcopy(df_statistics)
df.sort_values(by=['Labels Retraining %'], ascending=[False], inplace=True)
df[df['Error Based'] == 'True'][(df['Sampling'] == 'entropy')]
# Out:
#                           filename Model Error Based  Initial Instances  \
# 8   2020_11_09_12_55_41_995.pickle    Xg        True             2642.0
# 1   2020_11_09_12_47_23_389.pickle    Xg        True             2642.0
# 12  2020_11_09_12_38_55_675.pickle    Xg        True             2642.0
# 3   2020_11_09_12_30_42_478.pickle    Xg        True             2642.0
# 2   2020_11_09_12_22_58_435.pickle    Xg        True             2642.0
#
#     Approach  Retrainsize  Samplesize Base Detector  Ad Delta Ks Alpha  \
# 8   Standard        528.0         1.0         adwin     0.001     None
# 1   Standard        528.0         1.0         adwin     0.001     None
# 12  Standard        528.0         1.0         adwin     0.001     None
# 3   Standard        528.0         1.0         adwin     0.001     None
# 2   Standard        528.0         1.0         adwin     0.001     None
#
#    Ph Alpha Ph Delta Ph Min Inst Ph Threshold  FAC  MDC    MDR      MTD  MTFA  \
# 8      None     None        None         None  0.0  4.0  0.364  573.571   0.0
# 1      None     None        None         None  0.0  2.0  0.182  532.556   0.0
# 12     None     None        None         None  0.0  3.0  0.273  451.750   0.0
# 3      None     None        None         None  0.0  2.0  0.182  569.222   0.0
# 2      None     None        None         None  0.0  3.0  0.273  467.000   0.0
#
#     MTR                                  True Drift Points  \
# 8   0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 1   0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 12  0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 3   0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
# 2   0.0  [10000, 11610, 15100, 16858, 25000, 30598, 355...
#
#                                      Triggered Drifts  Detections Count  \
# 8   [10175, 11839, 26751, 30623, 37279, 45471, 49503]               7.0
# 1   [10175, 11839, 26623, 30815, 35903, 36159, 379...               9.0
# 12  [10175, 11839, 26687, 30783, 35711, 36287, 449...               8.0
# 3   [10175, 11839, 19007, 25791, 30847, 35775, 366...               9.0
# 2   [10175, 11935, 15871, 16991, 31359, 35839, 376...               8.0
#
#     Labels Detection %  Labels Retraining % Sampling  Weighted F1    Mcc  \
# 8                100.0                 90.0  entropy        0.591  0.508
# 1                100.0                 80.0  entropy        0.604  0.522
# 12               100.0                 60.0  entropy        0.594  0.511
# 3                100.0                 40.0  entropy        0.630  0.564
# 2                100.0                 20.0  entropy        0.579  0.502
#
#     ROC_AUC    Acc
# 8     0.887  0.590
# 1     0.895  0.601
# 12    0.891  0.592
# 3     0.907  0.635
# 2     0.882  0.583

# %%
window_size = 100
# compute rolling mean of accuracy
dist_series = pd.Series(acc_list)
windows = dist_series.rolling(window_size)
moving_averages = windows.mean()
moving_averages_list = moving_averages.tolist()

# %%
plt.style.use('seaborn-white')
fig, ax = plt.subplots(1)
ax.tick_params(axis='both', which='major', labelsize=20)

ax.hlines(1,0, len(acc_list), color='tab:red', label='Error 100%', lw = 2)
for i in np.array(df[df['filename'] == '2020_11_09_12_59_31_148.pickle']['Triggered Drifts'])[0]:
    ax.plot(i,1, marker='x', color='red', mew=4, ms=20)
    #ax.plot(i,6, marker='x', color='red', mew=3, ms=15)

    
ax.hlines(2,0, len(acc_list), color='tab:orange', label='Entropy 90%', lw = 2)
for i in np.array(df[df['filename'] == '2020_11_09_12_55_41_995.pickle']['Triggered Drifts'])[0]:
    ax.plot(i,2, marker='x', color='orange', mew=4, ms=20)
    
    
ax.hlines(3,0, len(acc_list), color='tab:blue', label='Entropy 80%', lw = 2)
for i in np.array(df[df['filename'] == '2020_11_09_12_47_23_389.pickle']['Triggered Drifts'])[0]:
    ax.plot(i,3, marker='x', color='blue', mew=4, ms=20)
    
    
ax.hlines(4,0, len(acc_list), color='tab:purple', label='Entropy 60%', lw = 2)
for i in np.array(df[df['filename'] == '2020_11_09_12_38_55_675.pickle']['Triggered Drifts'])[0]:
    ax.plot(i,4, marker='x', color='purple', mew=4, ms=20)
    
    
ax.hlines(5,0, len(acc_list), color='tab:brown', label='Entropy 40%', lw = 2)
for i in np.array(df[df['filename'] == '2020_11_09_12_30_42_478.pickle']['Triggered Drifts'])[0]:
    ax.plot(i,5, marker='x', color='brown', mew=4, ms=20)
    
ax.hlines(6,0, len(acc_list), color='tab:green', label='Entropy 20%', lw = 2)
for i in np.array(df[df['filename'] == '2020_11_09_12_22_58_435.pickle']['Triggered Drifts'])[0]:
    ax.plot(i,6, marker='x', color='green', mew=4, ms=20)
    

for i in df.iloc[0,:]['True Drift Points']:
    plt.axvline(x=i, color = 'red', linewidth = 2)

ax.legend(bbox_to_anchor=(1.01,0), loc="lower right",  bbox_transform=fig.transFigure, fontsize = 30)
ax.set_yticks([])
ax.set_xticks(np.arange(0, len(moving_averages_list), 5000))
ax.tick_params(axis='both', which='major', labelsize=35)

ax2 = ax.twinx()
ax2.plot(np.array(moving_averages_list), color='grey', linewidth = 0.8)
ax2.tick_params(axis='y', labelcolor='black')
ax2.set_yticks(np.arange(0, 1.1, 0.1))
ax2.tick_params(axis='both', which='major', labelsize=35)


fig.set_size_inches(40,12)
fig.tight_layout() 



plt.xticks(fontsize=5)
#plt.savefig("../Results/Plots/points_ins_INC_ABR_shap_entropy.jpg") 
plt.show()
